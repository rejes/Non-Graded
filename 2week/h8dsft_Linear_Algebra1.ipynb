# %% [markdown]
# # NG 4
#
# Vektor

# %% [markdown]
# #### 1. Buatlah vektor dengan python

# %%
vektor=[17,22,19]

# %%
print(vektor)
# Out:
# [17, 22, 19]

# %% [markdown]
# #### 2. Diberikan 3 buah vector 3 dimensi:

# %%
import numpy as np

# %% [markdown]
#      a. Vektor 3 Dimensi

# %%
A = np.array([[[17,22,19]]])
B = np.array([[[10,20,11]]])
C = np.array([[[5,12,9]]])

# %% [markdown]
#     b. Menjumlahkan A+B

# %%
jumlah = A+B
print(jumlah)
# Out:
# [[[27 42 30]]]

# %% [markdown]
#     c. Pengurangan B-C

# %%
pengurangan = B-C
print(pengurangan)
# Out:
# [[[5 8 2]]]

# %% [markdown]
#     d. A dot C

# %%
A = np.array([17,22,19])
C = np.array([5,12,9])

dotproduct=np.dot(A,C)
print(dotproduct)
# Out:
# 520

# %% [markdown]
#     e. A x B

# %%
kali = A*B
print(kali)
# Out:
# [[[170 440 209]]]

# %% [markdown]
#     f. norm A

# %%
#Cara 1
nilai_a=np.array([17,22,19])
mengeksekusi=np.linalg.norm(nilai_a)
print(mengeksekusi)
# Out:
# 33.67491648096547

# %%
L1=np.linalg.norm(nilai_a,1)
print(L1)
# Out:
# 58.0

# %%
#Cara 2
L2=np.linalg.norm(nilai_a,2)
print(L2)
# Out:
# 33.67491648096547

# %%
#Cara 3
norm = 0
for i in range( len( nilai_a ) ):
  norm+=nilai_a[ i ]**2
norm=np.sqrt( norm )
print(norm)
# Out:
# 33.67491648096547

# %% [markdown]
#     g. Sudut antara vektor A dan B

# %%
A = np.array([17,22,19])
B = np.array([10,20,11])
vektAB=(A@B)/(np.linalg.norm(A)* np.linalg.norm(B))
print(vektAB)
# Out:
# 0.9759590023331435

# %%
hasil = np.arccos(vektAB)
print(hasil)
# Out:
# 0.21971776576153962

# %% [markdown]
# #### 3. Membuat plot dari vector, kedalam 2D

# %%
import matplotlib.pyplot as plt

# %%
u = np.array([2, 5])
v = np.array([3, 1])

# %%
x_coords, y_coords = zip(u, v)
plt.scatter(x_coords, y_coords, color=["Red","Black"])
plt.axis([0, 9, 0, 6])
plt.grid()
plt.show()

# %%
def plot_vector2d(vector2d, origin=[0, 0], **options):
    return plt.arrow(origin[0], origin[1], vector2d[0], vector2d[1],
              head_width=0.2, head_length=0.3, length_includes_head=True,
              **options)
plot_vector2d(u, color="Red")
plot_vector2d(v, color="Black")
plt.axis([0, 9, 0, 6])
plt.grid()
plt.show()
