# %% [markdown]
# # NG 7

# %% [markdown]
# Turunan

# %%
import sympy as sy

# %% [markdown]
# 1. Mencari turunan dari fungsi

# %%
#membuat nilai x
nilai_x = sy.Symbol("nilai_x",real=True)
#Bagian Soal 1
print('y1 = x² + 2x + 1')
y1 = x**2+ 2*x +1 
#pengeksekusian turunan
print('hasil pertama :')
y1.diff(x)
# Out:
# y1 = x² + 2x + 1
# hasil pertama :
# 2*x + 2

# %%
#Bagian Soal 2
print('4x³ - 3x² + 2x - 1')
y2 = 4*x**3 - 3*x**2 + 2*x -1
print('hasil kedua :')
y2.diff(x)
# Out:
# 4x³ - 3x² + 2x - 1
# hasil kedua :
# 12*x**2 - 6*x + 2

# %%
y3 = y2.diff(x)
y3.diff(x)
# Out:
# 24*x - 6
