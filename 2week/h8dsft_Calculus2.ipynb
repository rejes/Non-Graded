# %% [markdown]
# # NG 8
# Integral

# %%
import numpy as np
import sympy as sy
from scipy import integrate

# %%
#membuat nilai x
#nilai_x = sy.Symbol("nilai_x",real=True)

print('integral dari fungsi berikut : 3x² - 6x + 3')
print('')
print('hasil')
a = 3*x**2 - 6*x + 3
a.integrate(x)
# Out:
# integral dari fungsi berikut : 3x² - 6x + 3
#
# hasil
# x**3 - 3*x**2 + 3*x

# %%
# integral menggunakan Numerical -Function
# Soal Bagian pertama
print('3x² - 6x + 3')
def f(x):
  return 3*x**2 - 6*x + 3 

print('hasil')
A = integrate.quad(f,0,10) # 0 nilai minimum - 10 nilai maximum mksdnya batasan nilai
print(A)
# Out:
# 3x² - 6x + 3
# hasil
# (730.0, 8.104628079763643e-12)

# %%
#integral menggunakan Numerical -Function
print('8x³ -  x² + 5x -1')
def f(x):
  return 8*x**3 - x**2 + 5*x - 1 

print('hasil')
B = integrate.quad(f,0,10)
print(B)
# Out:
# 8x³ -  x² + 5x -1
# hasil
# (19906.666666666668, 2.2101080867635875e-10)
