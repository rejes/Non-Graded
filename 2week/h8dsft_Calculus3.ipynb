# %%
import sympy as sy
from sympy.tensor.array import derive_by_array

# %%
x,y = sy.symbols('y,x')
nilai_w = 3*x + 4*y - 5

print('Mencari Gradient dari sebuah fungsi dengan nilai : 3x + 4y = 5')
print("")
print("hasil")
derive_by_array(nilai_w,(x,y))

#Numberpage15PPT
# Out:
# Mencari Gradient dari sebuah fungsi dengan nilai : 3x + 4y = 5
#
# hasil
# [3, 4]
