# %%
def kel_cel (cel):       # Memasukkan nama_fungsi dan (Parameter)
 return  273.15 + cel    # Rumus Kelvin

# Memasukkan nilai Suhu 280 dan mengeksekusi hasil return
print('Nilai Suhu Temperatur 280, celcius maka nilai Kelvin adalah :',kel_cel(280)) 

def cel_kel(kel):
  return kel - 273.15   # Rumus 

# Memasukkan nilai Suhu 280 dan mengeksekusi hasil return
print('Nilai Suhu Temperatur 280, kelvin maka celcius adalah :',cel_kel(280))

#Celcius ke Fahrenheit

#Memasukkan nama_fungsi dan (Parameter)
def konfersi_fahrenheit(conv,cel=True):
  if cel:                                          #Kondisi jika
    conv = (conv * 9 /5) + 32                      #Rumus
  else:                                            #Jika False Maka
# kelvin ke Fahrenheit
    conv = ((conv - 273.15) * 9 /5) + 32           #Rumus

    #Return untuk mengembalikan nilai dari sebuah function. 
    #Biasanya fungsi return terikat oleh fungsi
    
  return conv                           
  suhu = 280                                       #Memasukkan Nilai Suhu

  #Print untuk mencetak output / nilai. Print tidak terikat oleh fungsi.
print('Nilai Suhu Temperatur 280, Celcius maka Fahrenheit adalah :', konfersi_fahrenheit(suhu))
print('Nilai Suhu Temperatur 280, kelvin maka Fahrenheit adalah:',konfersi_fahrenheit(suhu, cel=False))
# Out:
# Nilai Suhu Temperatur 280, celcius maka nilai Kelvin adalah : 553.15
# Nilai Suhu Temperatur 280, kelvin maka celcius adalah : 6.850000000000023
# Nilai Suhu Temperatur 280, Celcius maka Fahrenheit adalah : 536.0
# Nilai Suhu Temperatur 280, kelvin maka Fahrenheit adalah: 44.33000000000004
